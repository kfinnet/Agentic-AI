# %% [markdown]
# <a href="https://colab.research.google.com/github/kfinnet/Trust-AI/blob/master/%5B1%EA%B0%95%5D_%EC%8B%9C%EC%9E%91%ED%95%98%EB%A9%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 기초 사용법

# %% [markdown]
# https://platform.openai.com/docs/quickstart?language=python

# %%
import os

os.environ["OPENAI_API_KEY"] = "sk-proj-xxx"

# %%
print(response.output_text)

# %% [markdown]
# ## Reasoning

# %% [markdown]
# https://platform.openai.com/docs/guides/text

# %%
prompt = """
앵무새의 털 색상이 여러개인 이유가 뭐야?
"""

response = client.responses.create(
    model="gpt-5-nano",
    # reasoning={"effort": "medium"},
    input=[
        {
            "role": "user",
            "content": prompt
        }
    ]
)

print(response.output_text)
